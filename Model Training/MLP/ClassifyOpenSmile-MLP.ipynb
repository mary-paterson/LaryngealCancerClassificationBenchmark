# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import balanced_accuracy_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.utils.class_weight import compute_class_weight
from sklearn.tree import DecisionTreeClassifier
from sklearn.compose import ColumnTransformer

import joblib

import matplotlib.pyplot as plt
import seaborn as sns
import os

from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImPipeline
from sklearn.neural_network import MLPClassifier

# %%
cwd = os.getcwd()

# %%
parent_dir = os.path.dirname(cwd)
parent_dir = os.path.dirname(parent_dir)

# %%
train_files = joblib.load(f'{parent_dir}/FEMH_train_files.pkl')
test_files = joblib.load(f'{parent_dir}/FEMH_test_files.pkl')

# %%
femh_df = pd.read_csv(f"{parent_dir}/Raw Features/OpenSmile_FEMH.csv", index_col=0)
femh_df['filename'] = femh_df['file'].str.split('.', expand=True)[0]
femh_df = femh_df.drop(['file'], axis=1)
femh_df.head()
# Out:
#    F0semitoneFrom27.5Hz_sma3nz_amean  F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                          34.883045                                0.017140
# 1                          29.470533                                0.265424
# 2                          37.683495                                0.003717
# 3                          27.864012                                0.013270
# 4                          44.434470                                0.090572
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                   34.455215
# 1                                   23.582480
# 2                                   37.581398
# 3                                   27.567318
# 4                                   44.116726
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                   34.960484
# 1                                   31.078848
# 2                                   37.688583
# 3                                   27.804457
# 4                                   44.907550
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                   35.348810
# 1                                   36.680910
# 2                                   37.774850
# 3                                   28.188667
# 4                                   45.512920
#
#    F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                  0.893593
# 1                                 13.098429
# 2                                  0.193451
# 3                                  0.621349
# 4                                  1.396195
#
#    F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# 0                                    12.763138
# 1                                    22.764477
# 2                                     2.640856
# 3                                     7.550055
# 4                                   338.165250
#
#    F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  \
# 0                                       4.539836
# 1                                      82.978890
# 2                                       1.785011
# 3                                       2.329901
# 4                                     294.367580
#
#    F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope  \
# 0                                      9.080422
# 1                                     60.700874
# 2                                      0.939009
# 3                                      9.683333
# 4                                     41.631023
#
#    F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope  ...  \
# 0                                        7.009194  ...
# 1                                       12.533890  ...
# 2                                        0.305288  ...
# 3                                        3.817906  ...
# 4                                       40.313984  ...
#
#    spectralFluxUV_sma3nz_amean  loudnessPeaksPerSec  VoicedSegmentsPerSec  \
# 0                     0.000000             2.512563              0.518135
# 1                     0.569495             3.030303              3.260870
# 2                     0.000000             3.010033              0.341297
# 3                     0.000000             6.688963              0.341297
# 4                     3.321110             6.020067              0.682594
#
#    MeanVoicedSegmentLengthSec  StddevVoicedSegmentLengthSec  \
# 0                       1.920                       0.00000
# 1                       0.160                       0.07874
# 2                       2.920                       0.00000
# 3                       2.920                       0.00000
# 4                       1.445                       0.29500
#
#    MeanUnvoicedSegmentLength  StddevUnvoicedSegmentLength  \
# 0                   0.000000                     0.000000
# 1                   0.123333                     0.090308
# 2                   0.000000                     0.000000
# 3                   0.000000                     0.000000
# 4                   0.000000                     0.000000
#
#    equivalentSoundLevel_dBp  pathology         filename
# 0                -17.993633    Atrophy  Atrophy-00002mg
# 1                -16.225655    Atrophy  Atrophy-0001297
# 2                -28.936941    Atrophy  Atrophy-0001apo
# 3                -20.353485    Atrophy  Atrophy-0001qd3
# 4                -13.894936    Atrophy  Atrophy-0002ipt
#
# [5 rows x 90 columns]

# %%
demographics = pd.read_pickle(f'{parent_dir}/Audio/medicalhistory.pkl')
demographics = demographics.drop(['ID', 'Disease category', 'pathology'], axis=1)
demographics = demographics[['Sex', 'Age', 'filename']]
# demographics = demographics.drop(['Sex', 'Age'], axis=1)
demographics.head()
# Out:
#   Sex Age         filename
# 0   1  97  Atrophy-00002mg
# 1   1  86  Atrophy-0001297
# 2   2  45  Atrophy-0001apo
# 3   1  75  Atrophy-0001qd3
# 4   1  64  Atrophy-0002ipt

# %%
df = pd.merge(femh_df, demographics, on='filename', how='inner')
df = femh_df.copy()
df.head()
# Out:
#    F0semitoneFrom27.5Hz_sma3nz_amean  F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                          34.883045                                0.017140
# 1                          29.470533                                0.265424
# 2                          37.683495                                0.003717
# 3                          27.864012                                0.013270
# 4                          44.434470                                0.090572
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                   34.455215
# 1                                   23.582480
# 2                                   37.581398
# 3                                   27.567318
# 4                                   44.116726
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                   34.960484
# 1                                   31.078848
# 2                                   37.688583
# 3                                   27.804457
# 4                                   44.907550
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                   35.348810
# 1                                   36.680910
# 2                                   37.774850
# 3                                   28.188667
# 4                                   45.512920
#
#    F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                  0.893593
# 1                                 13.098429
# 2                                  0.193451
# 3                                  0.621349
# 4                                  1.396195
#
#    F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# 0                                    12.763138
# 1                                    22.764477
# 2                                     2.640856
# 3                                     7.550055
# 4                                   338.165250
#
#    F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  \
# 0                                       4.539836
# 1                                      82.978890
# 2                                       1.785011
# 3                                       2.329901
# 4                                     294.367580
#
#    F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope  \
# 0                                      9.080422
# 1                                     60.700874
# 2                                      0.939009
# 3                                      9.683333
# 4                                     41.631023
#
#    F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope  ...  \
# 0                                        7.009194  ...
# 1                                       12.533890  ...
# 2                                        0.305288  ...
# 3                                        3.817906  ...
# 4                                       40.313984  ...
#
#    spectralFluxUV_sma3nz_amean  loudnessPeaksPerSec  VoicedSegmentsPerSec  \
# 0                     0.000000             2.512563              0.518135
# 1                     0.569495             3.030303              3.260870
# 2                     0.000000             3.010033              0.341297
# 3                     0.000000             6.688963              0.341297
# 4                     3.321110             6.020067              0.682594
#
#    MeanVoicedSegmentLengthSec  StddevVoicedSegmentLengthSec  \
# 0                       1.920                       0.00000
# 1                       0.160                       0.07874
# 2                       2.920                       0.00000
# 3                       2.920                       0.00000
# 4                       1.445                       0.29500
#
#    MeanUnvoicedSegmentLength  StddevUnvoicedSegmentLength  \
# 0                   0.000000                     0.000000
# 1                   0.123333                     0.090308
# 2                   0.000000                     0.000000
# 3                   0.000000                     0.000000
# 4                   0.000000                     0.000000
#
#    equivalentSoundLevel_dBp  pathology         filename
# 0                -17.993633    Atrophy  Atrophy-00002mg
# 1                -16.225655    Atrophy  Atrophy-0001297
# 2                -28.936941    Atrophy  Atrophy-0001apo
# 3                -20.353485    Atrophy  Atrophy-0001qd3
# 4                -13.894936    Atrophy  Atrophy-0002ipt
#
# [5 rows x 90 columns]

# %%
df['pathology'].value_counts()
# Out:
# pathology
# Polyp                       202
# Nodules                     200
# Atrophy                     189
# Cyst                        175
# Vocal paresis               164
# Vocal palsy                 164
# Reinke’s edema              144
# Sulcus                      127
# Muscle tension dysphonia    117
# Presbyphonia                115
# Vocal process granuloma      86
# Fibrous mass                 84
# Ulcer                        64
# Spasmodic dysphonia          34
# Laryngeal cancer             31
# Dysplasia                    29
# Papilloma                    28
# Tremor                       18
# Scar                         15
# Varix                        14
# Name: count, dtype: int64

# %%
# Pathologies to be replaced with "Malignant"
malignant_pathologies = ['Laryngeal cancer', 'Dysplasia']

# Replace specified pathologies with "Malignant"
df['pathology'] = df['pathology'].apply(lambda x: 'Malignant' if x in malignant_pathologies else 'Benign')

# %%
df['pathology'].value_counts()
# Out:
# pathology
# Benign       1940
# Malignant      60
# Name: count, dtype: int64

# %%
train_df = df[df['filename'].isin(train_files)]
train_df = train_df.reset_index(drop=True)

# %%
X_train = train_df.drop(['pathology', 'filename'], axis=1)
y_train = train_df['pathology']

# %%
X_train.shape
# Out:
# (1340, 88)

# %%
audio_features = femh_df.columns.drop(['pathology', 'filename'])
audio_features
# Out:
# Index(['F0semitoneFrom27.5Hz_sma3nz_amean',
#        'F0semitoneFrom27.5Hz_sma3nz_stddevNorm',
#        'F0semitoneFrom27.5Hz_sma3nz_percentile20.0',
#        'F0semitoneFrom27.5Hz_sma3nz_percentile50.0',
#        'F0semitoneFrom27.5Hz_sma3nz_percentile80.0',
#        'F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2',
#        'F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope',
#        'F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope',
#        'F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope',
#        'F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope', 'loudness_sma3_amean',
#        'loudness_sma3_stddevNorm', 'loudness_sma3_percentile20.0',
#        'loudness_sma3_percentile50.0', 'loudness_sma3_percentile80.0',
#        'loudness_sma3_pctlrange0-2', 'loudness_sma3_meanRisingSlope',
#        'loudness_sma3_stddevRisingSlope', 'loudness_sma3_meanFallingSlope',
#        'loudness_sma3_stddevFallingSlope', 'spectralFlux_sma3_amean',
#        'spectralFlux_sma3_stddevNorm', 'mfcc1_sma3_amean',
#        'mfcc1_sma3_stddevNorm', 'mfcc2_sma3_amean', 'mfcc2_sma3_stddevNorm',
#        'mfcc3_sma3_amean', 'mfcc3_sma3_stddevNorm', 'mfcc4_sma3_amean',
#        'mfcc4_sma3_stddevNorm', 'jitterLocal_sma3nz_amean',
#        'jitterLocal_sma3nz_stddevNorm', 'shimmerLocaldB_sma3nz_amean',
#        'shimmerLocaldB_sma3nz_stddevNorm', 'HNRdBACF_sma3nz_amean',
#        'HNRdBACF_sma3nz_stddevNorm', 'logRelF0-H1-H2_sma3nz_amean',
#        'logRelF0-H1-H2_sma3nz_stddevNorm', 'logRelF0-H1-A3_sma3nz_amean',
#        'logRelF0-H1-A3_sma3nz_stddevNorm', 'F1frequency_sma3nz_amean',
#        'F1frequency_sma3nz_stddevNorm', 'F1bandwidth_sma3nz_amean',
#        'F1bandwidth_sma3nz_stddevNorm', 'F1amplitudeLogRelF0_sma3nz_amean',
#        'F1amplitudeLogRelF0_sma3nz_stddevNorm', 'F2frequency_sma3nz_amean',
#        'F2frequency_sma3nz_stddevNorm', 'F2bandwidth_sma3nz_amean',
#        'F2bandwidth_sma3nz_stddevNorm', 'F2amplitudeLogRelF0_sma3nz_amean',
#        'F2amplitudeLogRelF0_sma3nz_stddevNorm', 'F3frequency_sma3nz_amean',
#        'F3frequency_sma3nz_stddevNorm', 'F3bandwidth_sma3nz_amean',
#        'F3bandwidth_sma3nz_stddevNorm', 'F3amplitudeLogRelF0_sma3nz_amean',
#        'F3amplitudeLogRelF0_sma3nz_stddevNorm', 'alphaRatioV_sma3nz_amean',
#        'alphaRatioV_sma3nz_stddevNorm', 'hammarbergIndexV_sma3nz_amean',
#        'hammarbergIndexV_sma3nz_stddevNorm', 'slopeV0-500_sma3nz_amean',
#        'slopeV0-500_sma3nz_stddevNorm', 'slopeV500-1500_sma3nz_amean',
#        'slopeV500-1500_sma3nz_stddevNorm', 'spectralFluxV_sma3nz_amean',
#        'spectralFluxV_sma3nz_stddevNorm', 'mfcc1V_sma3nz_amean',
#        'mfcc1V_sma3nz_stddevNorm', 'mfcc2V_sma3nz_amean',
#        'mfcc2V_sma3nz_stddevNorm', 'mfcc3V_sma3nz_amean',
#        'mfcc3V_sma3nz_stddevNorm', 'mfcc4V_sma3nz_amean',
#        'mfcc4V_sma3nz_stddevNorm', 'alphaRatioUV_sma3nz_amean',
#        'hammarbergIndexUV_sma3nz_amean', 'slopeUV0-500_sma3nz_amean',
#        'slopeUV500-1500_sma3nz_amean', 'spectralFluxUV_sma3nz_amean',
#        'loudnessPeaksPerSec', 'VoicedSegmentsPerSec',
#        'MeanVoicedSegmentLengthSec', 'StddevVoicedSegmentLengthSec',
#        'MeanUnvoicedSegmentLength', 'StddevUnvoicedSegmentLength',
#        'equivalentSoundLevel_dBp'],
#       dtype='object')

# %%
symptom_features = X_train.columns.drop(audio_features)
symptom_features
# Out:
# Index([], dtype='object')

# %%
# Define the preprocessing and feature selection for audio features
audio_preprocessing = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),  # Imputer step
    ('scaler', StandardScaler()),  # Scaling step
    ('feature_selection', SelectFromModel(DecisionTreeClassifier(random_state=42)))  # Feature Selection
])

# %%
# Define the preprocessing for symptoms (imputation and scaling only)
symptom_preprocessing = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value=0)),  # Imputer step
    ('scaler', StandardScaler())  # Scaling step
])

# %%
# Combine the preprocessing and feature selection for audio features with symptom preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('audio', audio_preprocessing, audio_features),
        ('symptoms', symptom_preprocessing, symptom_features)
    ]
)

# %%
pipeline = ImPipeline(steps=[
('preprocessor', preprocessor),
('smote', SMOTE(random_state=42)),  # SMOTE for handling class imbalance
('classifier', MLPClassifier(random_state=42, early_stopping=True)) # MLP Classifier step
])

# %%
param_grid = {
    'classifier__hidden_layer_sizes': [(50,), (100,), (100, 50), (100, 100), (50, 50, 50)],
    'classifier__activation': ['relu', 'tanh'],
    'classifier__solver': ['adam', 'sgd', 'lbfgs'],
    'classifier__learning_rate': ['constant', 'invscaling', 'adaptive'],
}

# %%
# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=pipeline, param_grid=param_grid, cv=5, scoring='balanced_accuracy', verbose=3, return_train_score=True)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.929, test=0.626) total time=   0.6s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.829, test=0.657) total time=   0.3s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.974, test=0.601) total time=   0.6s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.797, test=0.560) total time=   0.2s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.976, test=0.572) total time=   0.5s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.812, test=0.636) total time=   0.5s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.780, test=0.703) total time=   0.3s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.819, test=0.601) total time=   0.4s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.811, test=0.626) total time=   0.5s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.839, test=0.563) total time=   0.4s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.492) total time=   0.1s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.496) total time=   0.2s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.485) total time=   0.1s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.550) total time=   0.1s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.552) total time=   0.1s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.929, test=0.626) total time=   0.4s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.829, test=0.657) total time=   0.3s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.974, test=0.601) total time=   0.6s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.797, test=0.560) total time=   0.2s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.976, test=0.572) total time=   0.5s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.482, test=0.489) total time=   0.1s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.468, test=0.482) total time=   0.1s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.496, test=0.496) total time=   0.1s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.641, test=0.642) total time=   0.2s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.510, test=0.489) total time=   0.1s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.492) total time=   0.1s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.496) total time=   0.2s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.485) total time=   0.1s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.550) total time=   0.1s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.552) total time=   0.1s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.929, test=0.626) total time=   0.4s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.829, test=0.657) total time=   0.3s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.974, test=0.601) total time=   0.6s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.797, test=0.560) total time=   0.2s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.976, test=0.572) total time=   0.5s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.818, test=0.634) total time=   0.7s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.780, test=0.703) total time=   0.7s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.819, test=0.601) total time=   0.7s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.811, test=0.626) total time=   1.0s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.844, test=0.567) total time=   0.7s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.492) total time=   0.1s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.496) total time=   0.2s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.485) total time=   0.1s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.550) total time=   0.1s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.552) total time=   0.1s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.958, test=0.659) total time=   0.6s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.970, test=0.691) total time=   1.0s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.948, test=0.587) total time=   0.6s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.947, test=0.467) total time=   0.5s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.984, test=0.578) total time=   0.9s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.797, test=0.629) total time=   0.6s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.823, test=0.923) total time=   0.5s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.802, test=0.530) total time=   1.0s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.798, test=0.474) total time=   0.6s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.894, test=0.517) total time=   1.3s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.473) total time=   0.2s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.492) total time=   0.3s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.481) total time=   0.2s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.558) total time=   0.2s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.539) total time=   0.3s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.958, test=0.659) total time=   0.7s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.970, test=0.691) total time=   1.1s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.948, test=0.587) total time=   0.7s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.947, test=0.467) total time=   0.6s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.984, test=0.578) total time=   0.9s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.504, test=0.372) total time=   0.2s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.469, test=0.489) total time=   0.2s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.350, test=0.287) total time=   0.2s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.628, test=0.388) total time=   0.2s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.526, test=0.348) total time=   0.3s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.473) total time=   0.2s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.492) total time=   0.3s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.481) total time=   0.2s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.558) total time=   0.2s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.539) total time=   0.2s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.958, test=0.659) total time=   0.6s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.970, test=0.691) total time=   0.9s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.948, test=0.587) total time=   0.6s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.947, test=0.467) total time=   0.5s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.984, test=0.578) total time=   0.9s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.797, test=0.629) total time=   1.2s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.823, test=0.923) total time=   1.0s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.802, test=0.530) total time=   1.5s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.798, test=0.474) total time=   1.2s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.894, test=0.517) total time=   1.7s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.473) total time=   0.2s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.492) total time=   0.3s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.481) total time=   0.2s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.558) total time=   0.2s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100,), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.539) total time=   0.2s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.996, test=0.554) total time=   1.0s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.993, test=0.566) total time=   1.2s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.989, test=0.543) total time=   0.7s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=1.000, test=0.489) total time=   0.9s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.996, test=0.525) total time=   0.8s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.812, test=0.576) total time=   1.5s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.780, test=0.663) total time=   0.7s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.788, test=0.580) total time=   0.6s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.786, test=0.543) total time=   1.0s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.875, test=0.509) total time=   1.2s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.556) total time=   0.3s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.492) total time=   0.5s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.483) total time=   0.3s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.481) total time=   0.3s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.554) total time=   0.4s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.996, test=0.554) total time=   1.0s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.993, test=0.566) total time=   1.2s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.989, test=0.543) total time=   0.8s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=1.000, test=0.489) total time=   0.9s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.996, test=0.525) total time=   0.9s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.504, test=0.525) total time=   0.3s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.490, test=0.487) total time=   0.4s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.510, test=0.542) total time=   0.3s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.609, test=0.558) total time=   0.6s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.548, test=0.488) total time=   0.3s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.556) total time=   0.3s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.492) total time=   0.5s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.483) total time=   0.3s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.481) total time=   0.3s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.554) total time=   0.4s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.996, test=0.554) total time=   1.0s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.993, test=0.566) total time=   1.2s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.989, test=0.543) total time=   0.7s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=1.000, test=0.489) total time=   0.9s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.996, test=0.525) total time=   0.9s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.812, test=0.576) total time=   2.3s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.790, test=0.666) total time=   1.7s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.788, test=0.580) total time=   1.6s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.786, test=0.543) total time=   2.0s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.875, test=0.509) total time=   2.0s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.556) total time=   0.3s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.492) total time=   0.5s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.483) total time=   0.3s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.481) total time=   0.3s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 50), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.554) total time=   0.4s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.992, test=0.554) total time=   1.1s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.993, test=0.639) total time=   1.4s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.991, test=0.548) total time=   0.9s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.996, test=0.483) total time=   1.0s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.994, test=0.605) total time=   1.0s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.775, test=0.648) total time=   1.9s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.839, test=0.664) total time=   2.7s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.786, test=0.526) total time=   1.3s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.788, test=0.669) total time=   1.0s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.812, test=0.641) total time=   1.2s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.620) total time=   0.6s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.494) total time=   0.9s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.489) total time=   0.5s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.554) total time=   0.6s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.541) total time=   0.7s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.992, test=0.554) total time=   1.1s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.993, test=0.639) total time=   1.3s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.991, test=0.548) total time=   0.9s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.996, test=0.483) total time=   1.0s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.994, test=0.605) total time=   1.0s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.532, test=0.585) total time=   0.6s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.530, test=0.532) total time=   0.5s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.482, test=0.495) total time=   0.4s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.498, test=0.551) total time=   0.4s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.512, test=0.611) total time=   0.4s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.620) total time=   0.6s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.494) total time=   0.8s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.489) total time=   0.5s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.554) total time=   0.6s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.541) total time=   0.7s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.992, test=0.554) total time=   1.1s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.993, test=0.639) total time=   1.3s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.991, test=0.548) total time=   0.8s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.996, test=0.483) total time=   1.0s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.994, test=0.605) total time=   1.0s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.781, test=0.655) total time=   3.5s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.839, test=0.664) total time=   4.1s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.786, test=0.526) total time=   2.8s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.798, test=0.677) total time=   2.4s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.836, test=0.648) total time=   2.9s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.620) total time=   0.7s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.494) total time=   0.9s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.489) total time=   0.5s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.554) total time=   0.6s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.541) total time=   0.7s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.994, test=0.550) total time=   0.7s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.996, test=0.496) total time=   1.0s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.995, test=0.547) total time=   0.7s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.994, test=0.479) total time=   0.6s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.997, test=0.626) total time=   0.8s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.793, test=0.661) total time=   1.3s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.813, test=0.738) total time=   1.3s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.875, test=0.628) total time=   2.1s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.818, test=0.545) total time=   1.2s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.845, test=0.590) total time=   1.3s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.547) total time=   0.5s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.494) total time=   0.5s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.481) total time=   0.4s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.471) total time=   0.3s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.547) total time=   0.5s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.994, test=0.550) total time=   0.7s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.996, test=0.496) total time=   0.9s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.995, test=0.547) total time=   0.7s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.994, test=0.479) total time=   0.6s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.997, test=0.626) total time=   0.8s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.501, test=0.502) total time=   0.2s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.510, test=0.506) total time=   0.3s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.500, test=0.500) total time=   0.3s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.447, test=0.362) total time=   0.2s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.502, test=0.508) total time=   0.3s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.547) total time=   0.5s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.494) total time=   0.5s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.481) total time=   0.4s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.471) total time=   0.4s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.547) total time=   0.5s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.994, test=0.550) total time=   0.7s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.996, test=0.496) total time=   0.9s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.995, test=0.547) total time=   0.7s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.994, test=0.479) total time=   0.6s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.997, test=0.626) total time=   0.7s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.793, test=0.661) total time=   2.2s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.813, test=0.738) total time=   2.2s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.885, test=0.564) total time=   3.3s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.818, test=0.545) total time=   2.2s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.845, test=0.590) total time=   2.2s
# [CV 1/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.547) total time=   0.5s
# [CV 2/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.494) total time=   0.5s
# [CV 3/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.481) total time=   0.3s
# [CV 4/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.471) total time=   0.4s
# [CV 5/5] END classifier__activation=relu, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.547) total time=   0.5s
# [CV 1/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.880, test=0.580) total time=   0.3s
# [CV 2/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.761, test=0.771) total time=   0.2s
# [CV 3/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.800, test=0.503) total time=   0.2s
# [CV 4/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.840, test=0.617) total time=   0.3s
# [CV 5/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.950, test=0.518) total time=   0.5s
# [CV 1/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.768, test=0.619) total time=   0.4s
# [CV 2/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.767, test=0.833) total time=   0.4s
# [CV 3/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.800, test=0.694) total time=   0.3s
# [CV 4/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.786, test=0.721) total time=   0.5s
# [CV 5/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.793, test=0.591) total time=   0.3s
# [CV 1/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.535) total time=   0.1s
# [CV 2/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.560) total time=   0.2s
# [CV 3/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.612) total time=   0.1s
# [CV 4/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.479) total time=   0.1s
# [CV 5/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.591) total time=   0.1s
# [CV 1/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.880, test=0.580) total time=   0.3s
# [CV 2/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.761, test=0.771) total time=   0.2s
# [CV 3/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50,), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.800, test=0.503) total time=   0.2s
# ...
# [CV 1/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.532, test=0.638) total time=   0.5s
# [CV 2/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.641, test=0.563) total time=   0.4s
# [CV 3/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.615, test=0.326) total time=   1.2s
# [CV 4/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.499, test=0.581) total time=   0.8s
# [CV 5/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.638, test=0.560) total time=   1.1s
# [CV 1/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.477) total time=   0.7s
# [CV 2/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.485) total time=   1.0s
# [CV 3/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.628) total time=   0.6s
# [CV 4/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.489) total time=   0.6s
# [CV 5/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.518) total time=   0.7s
# [CV 1/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.975, test=0.589) total time=   1.1s
# [CV 2/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.987, test=0.556) total time=   2.2s
# [CV 3/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.984, test=0.533) total time=   1.6s
# [CV 4/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.828, test=0.677) total time=   0.4s
# [CV 5/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.985, test=0.495) total time=   1.4s
# [CV 1/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.756, test=0.563) total time=   3.3s
# [CV 2/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.786, test=0.655) total time=   3.7s
# [CV 3/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.809, test=0.526) total time=   2.8s
# [CV 4/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.766, test=0.629) total time=   2.2s
# [CV 5/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.834, test=0.554) total time=   3.3s
# [CV 1/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.477) total time=   0.7s
# [CV 2/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.485) total time=   1.0s
# [CV 3/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.628) total time=   0.6s
# [CV 4/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.489) total time=   0.6s
# [CV 5/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(100, 100), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.518) total time=   0.7s
# [CV 1/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.993, test=0.541) total time=   1.2s
# [CV 2/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.981, test=0.556) total time=   1.1s
# [CV 3/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.991, test=0.608) total time=   1.0s
# [CV 4/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.976, test=0.466) total time=   0.7s
# [CV 5/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=adam;, score=(train=0.983, test=0.566) total time=   0.7s
# [CV 1/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.753, test=0.602) total time=   0.4s
# [CV 2/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.761, test=0.719) total time=   1.1s
# [CV 3/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.823, test=0.582) total time=   1.0s
# [CV 4/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.828, test=0.534) total time=   1.3s
# [CV 5/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=sgd;, score=(train=0.757, test=0.518) total time=   0.4s
# [CV 1/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.547) total time=   0.4s
# [CV 2/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.492) total time=   0.5s
# [CV 3/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.620) total time=   0.3s
# [CV 4/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.473) total time=   0.3s
# [CV 5/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=constant, classifier__solver=lbfgs;, score=(train=1.000, test=0.456) total time=   0.5s
# [CV 1/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.993, test=0.541) total time=   1.2s
# [CV 2/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.981, test=0.556) total time=   1.1s
# [CV 3/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.991, test=0.608) total time=   1.0s
# [CV 4/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.976, test=0.466) total time=   0.7s
# [CV 5/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=adam;, score=(train=0.983, test=0.566) total time=   0.7s
# [CV 1/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.537, test=0.508) total time=   0.7s
# [CV 2/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.563, test=0.512) total time=   0.3s
# [CV 3/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.595, test=0.424) total time=   0.5s
# [CV 4/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.449, test=0.429) total time=   0.3s
# [CV 5/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=sgd;, score=(train=0.593, test=0.544) total time=   1.0s
# [CV 1/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.547) total time=   0.4s
# [CV 2/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.492) total time=   0.5s
# [CV 3/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.620) total time=   0.3s
# [CV 4/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.473) total time=   0.3s
# [CV 5/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=invscaling, classifier__solver=lbfgs;, score=(train=1.000, test=0.456) total time=   0.4s
# [CV 1/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.993, test=0.541) total time=   1.2s
# [CV 2/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.981, test=0.556) total time=   1.2s
# [CV 3/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.991, test=0.608) total time=   1.0s
# [CV 4/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.976, test=0.466) total time=   0.7s
# [CV 5/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=adam;, score=(train=0.983, test=0.566) total time=   0.6s
# [CV 1/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.753, test=0.602) total time=   1.5s
# [CV 2/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.772, test=0.721) total time=   2.2s
# [CV 3/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.823, test=0.582) total time=   2.1s
# [CV 4/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.828, test=0.534) total time=   2.5s
# [CV 5/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=sgd;, score=(train=0.757, test=0.518) total time=   1.4s
# [CV 1/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.547) total time=   0.4s
# [CV 2/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.492) total time=   0.5s
# [CV 3/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.620) total time=   0.3s
# [CV 4/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.473) total time=   0.3s
# [CV 5/5] END classifier__activation=tanh, classifier__hidden_layer_sizes=(50, 50, 50), classifier__learning_rate=adaptive, classifier__solver=lbfgs;, score=(train=1.000, test=0.456) total time=   0.4s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('audio',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler()),
#                                                                                          ('feature_selection',
#                                                                                           SelectFromModel(estimator=DecisionTreeClassifier(random_state=42)))]),
#                                                                          Index(['F0semitoneFrom27.5Hz_sma3nz_amean',
#        'F0semitoneFrom27.5Hz_sma3nz_stddevNorm',
#        'F...
#                                         MLPClassifier(early_stopping=True,
#                                                       random_state=42))]),
#              param_grid={'classifier__activation': ['relu', 'tanh'],
#                          'classifier__hidden_layer_sizes': [(50,), (100,),
#                                                             (100, 50),
#                                                             (100, 100),
#                                                             (50, 50, 50)],
#                          'classifier__learning_rate': ['constant', 'invscaling',
#                                                        'adaptive'],
#                          'classifier__solver': ['adam', 'sgd', 'lbfgs']},
#              return_train_score=True, scoring='balanced_accuracy', verbose=3)

# %%
# Best parameters from GridSearchCV
print(f'Best parameters: {grid_search.best_params_}')

# Best estimator from GridSearchCV
best_pipeline = grid_search.best_estimator_
# Out:
# Best parameters: {'classifier__activation': 'tanh', 'classifier__hidden_layer_sizes': (50,), 'classifier__learning_rate': 'adaptive', 'classifier__solver': 'sgd'}

# %%
cv_results = grid_search.cv_results_

best_index = grid_search.best_index_
print("Cross-validation results for the best parameters:")

print(f"Mean test score: {cv_results['mean_test_score'][best_index]}")
print(f"Mean train score: {cv_results['mean_train_score'][best_index]}")
# Out:
# Cross-validation results for the best parameters:
# Mean test score: 0.6927750410509032
# Mean train score: 0.7881773399014779

# %%
joblib.dump(grid_search, 'NN_OpenSmile_Rec_Only.pkl', compress=True)
# Out:
# ['NN_OpenSmile_Rec_Only.pkl']

# %% [markdown]
# # Test - holdout

# %%
test_df = df[df['filename'].isin(test_files)]
test_df = test_df.reset_index(drop=True)

# %%
X_test = test_df.drop(['pathology', 'filename'], axis=1)
y_test = test_df['pathology']

# %%
# Predict on the test set
y_pred = best_pipeline.predict(X_test)

# Evaluate the classifier
accuracy = balanced_accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.3f}')
# Out:
# Accuracy: 0.632

# %%
pathologies = df['pathology'].unique()
pathologies
# Out:
# array(['Benign', 'Malignant'], dtype=object)

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred, labels=pathologies)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm_norm, annot=cm, fmt='d', cmap='Blues', xticklabels=pathologies, yticklabels=pathologies)

plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix with Counts and Percentages')
plt.show()

# %%
import joblib
# best_pipeline = joblib.load('FeatureStates.pkl')

# %%
cwd = os.getcwd()
cwd
# Out:
# 'D:\\OneDrive\\Documents\\CDT\\Year4\\FEMH New Data\\FeatureSelection\\NN'

# %%
cwd_head = cwd

# %%
# Split the path into individual components
cwd_head = cwd
split_path = []
while True:
    head, tail = os.path.split(cwd_head)
    if tail == "":
        split_path.insert(0, head)  # Insert root (empty string) or drive part
        break
    split_path.insert(0, tail)
    cwd_head = head

# Get the first three components
base_path = split_path[:5]

# Join them back into a path string if needed
base_folder = os.path.join(*base_path)

# %%
base_folder
# Out:
# 'D:\\OneDrive\\Documents\\CDT\\Year4'

# %%
test_df = pd.read_csv(f"{base_folder}/Interspeech2024/INTERSPEECH2024/IssuesOfGeneralizability/FeatureExtraction/Raw Features/FeatureStates_SVD.csv", index_col=0)
test_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.398839 -0.617193 -0.595989  0.322591  0.391524  0.149125  0.441174
# 1  0.088389  1.413531 -1.209742  0.345088  0.348486  0.200700 -0.157992
# 2  0.538168 -0.739610 -1.322240  0.188341  0.466462 -0.145351  0.123136
# 3  0.288545 -0.635232 -1.093001  0.321708  0.605994  0.174163 -0.133413
# 4  0.668227 -0.455837 -0.669299  0.286863  0.577683  0.352189  0.422842
#
#           7         8         9  ...       504       505       506       507  \
# 0  0.125332  2.013796  0.090164  ... -0.011160 -0.160355  0.683657 -0.378355
# 1 -0.867997  1.328396  0.950012  ...  0.072722  1.230662  0.411054 -1.029371
# 2  0.222885  1.763254  0.403160  ... -0.236359 -0.559498  0.541930 -1.201554
# 3 -0.586694  2.820560  0.158068  ...  0.967324  1.050752  0.139838 -1.128331
# 4 -0.406255  1.895699  0.219177  ...  1.019589  0.029837  0.478853 -0.408324
#
#         508       509       510       511          file  pathology
# 0  0.128200 -0.235953  1.066113  0.485970  1047-a_n.wav     Cancer
# 1  0.858658 -0.000818 -0.376025  0.252415  1048-a_n.wav     Cancer
# 2  0.738980  0.066033  0.286256  0.639991   110-a_n.wav     Cancer
# 3  1.234023 -0.013407  0.322653  0.296545  1239-a_n.wav     Cancer
# 4  0.330384  0.307968  0.250254  0.736067  1245-a_n.wav     Cancer
#
# [5 rows x 514 columns]

# %%
test_df['pathology'].value_counts()
# Out:
# pathology
# Healthy        668
# Vocal palsy    196
# Cancer          38
# Name: count, dtype: int64

# %%
test_df['pathology new']=test_df['pathology'].str.replace('Healthy', 'Benign')
test_df['pathology new']=test_df['pathology new'].str.replace('Vocal palsy', 'Benign')

test_df['pathology new']=test_df['pathology new'].str.replace('Cancer', 'Malignant')

# %%
test_df['pathology new'].value_counts()
# Out:
# pathology new
# Benign       864
# Malignant     38
# Name: count, dtype: int64

# %%
# Prepare the features and labels
X_test = test_df.drop(['file', 'pathology', 'pathology new'], axis=1)
y_test = test_df['pathology new']

# %%
# Predict on the test set
y_pred = best_pipeline.predict(X_test)

# Evaluate the classifier
accuracy = balanced_accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.3f}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 # Predict on the test set
# ----> 2 y_pred = best_pipeline.predict(X_test)
#       4 # Evaluate the classifier
#       5 accuracy = balanced_accuracy_score(y_test, y_pred)
#
# File D:\Users\maryp\anaconda3\envs\speech_commands\Lib\site-packages\imblearn\pipeline.py:459, in Pipeline.predict(self, X, **params)
#     457 if not _routing_enabled():
#     458     for _, name, transform in self._iter(with_final=False):
# --> 459         Xt = transform.transform(Xt)
#     460     return self.steps[-1][1].predict(Xt, **params)
#     462 # metadata routing enabled
#
# File D:\Users\maryp\anaconda3\envs\speech_commands\Lib\site-packages\sklearn\utils\_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File D:\Users\maryp\anaconda3\envs\speech_commands\Lib\site-packages\sklearn\compose\_column_transformer.py:1003, in ColumnTransformer.transform(self, X, **params)
#    1001     diff = all_names - set(column_names)
#    1002     if diff:
# -> 1003         raise ValueError(f"columns are missing: {diff}")
#    1004 else:
#    1005     # ndarray was used for fitting or transforming, thus we only
#    1006     # check that n_features_in_ is consistent
#    1007     self._check_n_features(X, reset=False)
#
# ValueError: columns are missing: {'equivalentSoundLevel_dBp', 'mfcc3V_sma3nz_amean', 'spectralFlux_sma3_stddevNorm', 'F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2', 'mfcc1_sma3_amean', 'F2amplitudeLogRelF0_sma3nz_stddevNorm', 'loudnessPeaksPerSec', 'F1bandwidth_sma3nz_amean', 'alphaRatioUV_sma3nz_amean', 'F2frequency_sma3nz_amean', 'MeanUnvoicedSegmentLength', 'hammarbergIndexV_sma3nz_amean', 'HNRdBACF_sma3nz_amean', 'F0semitoneFrom27.5Hz_sma3nz_percentile50.0', 'F3frequency_sma3nz_stddevNorm', 'mfcc3_sma3_amean', 'loudness_sma3_percentile20.0', 'spectralFluxV_sma3nz_amean', 'StddevVoicedSegmentLengthSec', 'F0semitoneFrom27.5Hz_sma3nz_percentile80.0', 'F2frequency_sma3nz_stddevNorm', 'loudness_sma3_stddevRisingSlope', 'slopeV0-500_sma3nz_stddevNorm', 'slopeUV0-500_sma3nz_amean', 'F3bandwidth_sma3nz_amean', 'logRelF0-H1-H2_sma3nz_amean', 'hammarbergIndexUV_sma3nz_amean', 'mfcc2V_sma3nz_amean', 'loudness_sma3_meanFallingSlope', 'mfcc2V_sma3nz_stddevNorm', 'slopeV500-1500_sma3nz_amean', 'mfcc1V_sma3nz_stddevNorm', 'mfcc4V_sma3nz_stddevNorm', 'mfcc1_sma3_stddevNorm', 'mfcc4_sma3_amean', 'logRelF0-H1-A3_sma3nz_stddevNorm', 'VoicedSegmentsPerSec', 'F0semitoneFrom27.5Hz_sma3nz_stddevNorm', 'mfcc4_sma3_stddevNorm', 'F2bandwidth_sma3nz_amean', 'F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope', 'loudness_sma3_amean', 'F3frequency_sma3nz_amean', 'F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope', 'MeanVoicedSegmentLengthSec', 'loudness_sma3_percentile80.0', 'shimmerLocaldB_sma3nz_stddevNorm', 'slopeV500-1500_sma3nz_stddevNorm', 'alphaRatioV_sma3nz_amean', 'F2bandwidth_sma3nz_stddevNorm', 'mfcc2_sma3_amean', 'logRelF0-H1-H2_sma3nz_stddevNorm', 'F1frequency_sma3nz_amean', 'spectralFluxUV_sma3nz_amean', 'loudness_sma3_meanRisingSlope', 'mfcc3V_sma3nz_stddevNorm', 'loudness_sma3_stddevNorm', 'hammarbergIndexV_sma3nz_stddevNorm', 'mfcc4V_sma3nz_amean', 'F3amplitudeLogRelF0_sma3nz_stddevNorm', 'F1bandwidth_sma3nz_stddevNorm', 'HNRdBACF_sma3nz_stddevNorm', 'jitterLocal_sma3nz_stddevNorm', 'mfcc3_sma3_stddevNorm', 'F3amplitudeLogRelF0_sma3nz_amean', 'shimmerLocaldB_sma3nz_amean', 'F1amplitudeLogRelF0_sma3nz_stddevNorm', 'logRelF0-H1-A3_sma3nz_amean', 'loudness_sma3_percentile50.0', 'F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope', 'StddevUnvoicedSegmentLength', 'F0semitoneFrom27.5Hz_sma3nz_amean', 'mfcc1V_sma3nz_amean', 'F3bandwidth_sma3nz_stddevNorm', 'slopeUV500-1500_sma3nz_amean', 'F0semitoneFrom27.5Hz_sma3nz_percentile20.0', 'jitterLocal_sma3nz_amean', 'alphaRatioV_sma3nz_stddevNorm', 'spectralFlux_sma3_amean', 'loudness_sma3_pctlrange0-2', 'mfcc2_sma3_stddevNorm', 'loudness_sma3_stddevFallingSlope', 'slopeV0-500_sma3nz_amean', 'F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope', 'F1frequency_sma3nz_stddevNorm', 'F1amplitudeLogRelF0_sma3nz_amean', 'spectralFluxV_sma3nz_stddevNorm', 'F2amplitudeLogRelF0_sma3nz_amean'}

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred, labels=pathologies)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm_norm, annot=cm, fmt='d', cmap='Blues', xticklabels=pathologies, yticklabels=pathologies)

plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix with Counts and Percentages')
plt.show()
