# %%
import opensmile
import pandas as pd
import os

# %%
cwd = os.getcwd()

# %% [markdown]
# # Training Data

# %%
source_dir = f'{cwd}/Audio/'

# %%
smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.eGeMAPSv02,
    feature_level=opensmile.FeatureLevel.Functionals,
)

# %%
feats = smile.process_folder(source_dir)

# %%
feats.head()
# Out:
#                                                                            F0semitoneFrom27.5Hz_sma3nz_amean  \
# file                                               start  end
# D:\OneDrive\Documents\CDT\Year4\FEMH New Data\A... 0 days 0 days 00:00:02                          34.883045
# D:\OneDrive\Documents\CDT\Year4\FEMH New Data\A... 0 days 0 days 00:00:01                          29.470533
# D:\OneDrive\Documents\CDT\Year4\FEMH New Data\A... 0 days 0 days 00:00:03                          37.683495
# D:\OneDrive\Documents\CDT\Year4\FEMH New Data\A... 0 days 0 days 00:00:03                          27.864012
# D:\OneDrive\Documents\CDT\Year4\FEMH New Data\A... 0 days 0 days 00:00:03                          44.434471
#
#                                                                            F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# file                                               start  end
# ...

# %%
def format_features(df):
    df = df.reset_index()
    df = df.rename({'file': 'filename'}, axis=1)
    df['file'] = df['filename'].str.split('\\').str[-1]
    df['pathology'] = df['file'].str.split('-').str[0]
    df = df.drop(['start', 'end', 'filename'], axis=1)

    return df

# %%
feats_formatted = format_features(feats)
feats_formatted.head()
# Out:
#    F0semitoneFrom27.5Hz_sma3nz_amean  F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                          34.883045                                0.017140
# 1                          29.470533                                0.265424
# 2                          37.683495                                0.003717
# 3                          27.864012                                0.013270
# 4                          44.434471                                0.090572
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                   34.455215
# 1                                   23.582479
# 2                                   37.581398
# 3                                   27.567318
# 4                                   44.116726
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                   34.960484
# 1                                   31.078848
# 2                                   37.688583
# ...

# %%
feats_formatted['pathology'].value_counts()
# Out:
# pathology
# Polyp                       202
# Nodules                     200
# Atrophy                     189
# Cyst                        175
# Vocal paresis               164
# Vocal palsy                 164
# Reinke’s edema              144
# Sulcus                      127
# Muscle tension dysphonia    117
# Presbyphonia                115
# Vocal process granuloma      86
# Fibrous mass                 84
# Ulcer                        64
# Spasmodic dysphonia          34
# Laryngeal cancer             31
# Dysplasia                    29
# Papilloma                    28
# Tremor                       18
# Scar                         15
# Varix                        14
# Name: count, dtype: int64

# %%
feats_formatted.to_csv('Raw Features/OpenSmile_FEMH.csv')

# %% [markdown]
# # SVD'

# %%
source_dir = f'C:/Users/maryp/OneDrive/Documents/CDT/Data/Saarbruecken Voice Database/AllPathological/export'

# %%
smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.eGeMAPSv02,
    feature_level=opensmile.FeatureLevel.Functionals,
)

# %%
feats = smile.process_folder(source_dir)

# %%
feats.head()
# Out:
#                                                                                   F0semitoneFrom27.5Hz_sma3nz_amean  \
# file                                               start  end
# C:\Users\maryp\OneDrive\Documents\CDT\Data\Saar... 0 days 0 days 00:00:01.987060                          33.291927
# C:\Users\maryp\OneDrive\Documents\CDT\Data\Saar... 0 days 0 days 00:00:01.302120                          34.470200
# C:\Users\maryp\OneDrive\Documents\CDT\Data\Saar... 0 days 0 days 00:00:01.976060                          33.388988
# C:\Users\maryp\OneDrive\Documents\CDT\Data\Saar... 0 days 0 days 00:00:01.769580                          28.631144
# C:\Users\maryp\OneDrive\Documents\CDT\Data\Saar... 0 days 0 days 00:00:01.868920                          35.067646
#
#                                                                                   F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# file                                               start  end
# ...

# %%
def format_features(df):
    df = df.reset_index()
    df = df.rename({'file': 'filename'}, axis=1)
    df['file'] = df['filename'].str.split('\\').str[-1]
    df = df.drop(['start', 'end', 'filename'], axis=1)

    return df

# %%
feats_formatted = format_features(feats)
feats_formatted.head()
# Out:
#    F0semitoneFrom27.5Hz_sma3nz_amean  F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                          33.291927                                0.074908
# 1                          34.470200                                0.006657
# 2                          33.388988                                0.008550
# 3                          28.631144                                0.006550
# 4                          35.067646                                0.005973
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                   32.686474
# 1                                   34.262127
# 2                                   33.229641
# 3                                   28.475033
# 4                                   34.836266
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                   33.779255
# 1                                   34.468456
# 2                                   33.439896
# ...

# %%
feats_formatted.to_csv('Raw Features/OpenSmile_SVD.csv')
